# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv("data/cleaned_datasets-165618-377201-metacritic_games.csv", index_col=1)
df.head()
# Out:
#                                         platform              developer  \
# game
# Portal 2                                      PC         Valve Software
# The Elder Scrolls V: Skyrim                   PC  Bethesda Game Studios
# The Legend of Zelda: Ocarina of Time 3D      3DS                 GREZZO
# Batman: Arkham City                           PC     Rocksteady Studios
# Super Mario 3D Land                          3DS               Nintendo
#
#                                                     genre  release_date  \
# game
# Portal 2                                           Action  Apr 18, 2011
# The Elder Scrolls V: Skyrim                  Role-Playing  Nov 10, 2011
# The Legend of Zelda: Ocarina of Time 3D     Miscellaneous  Jun 19, 2011
# Batman: Arkham City                      Action Adventure  Nov 21, 2011
# Super Mario 3D Land                                Action  Nov 13, 2011
#
#                                          positive_critics  neutral_critics  \
# game
# ...

# %%
df.plot.scatter(x="metascore", y="user_score", alpha=0.5)

# %%
genre=df["genre"]
genre.value_counts()
genre = df['genre'].value_counts().keys().tolist()
count = df['genre'].value_counts().tolist()
del genre[30:52]
del count[30:52]
plt.barh(genre,count)
# Out:
# <BarContainer object of 31 artists>
