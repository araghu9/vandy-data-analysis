# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
dfCrit=pd.read_csv("data/cleaned_datasets-165618-377201-metacritic_games.csv", index_col=1)
dfSale=pd.read_csv("data/cleaned_vgsales.csv", index_col=1)

# %%
genre=dfCrit["genre"]
count = dfCrit['genre'].value_counts().tolist()
del count[30:52]
fig = plt.figure(figsize=(20, 5))
plt.xticks(rotation=90)
plt.xlabel("Genres")
plt.ylabel("Metascore")
plt.title("Metascores of various games in different genres")
plt.scatter(genre,dfCrit["metascore"])

# %%
genre=dfSale["genre"]
count = dfSale['genre'].value_counts().tolist()
del count[30:52]
fig = plt.figure(figsize=(20, 5))
plt.xticks(rotation=90)
plt.xlabel("Genres")
plt.ylabel("Global Sales(USD in millions)")
plt.title("Total revenue of various games in different genres")
plt.scatter(genre,dfSale["global_sales"])

# %%
genre=dfCrit["genre"]
genre = dfCrit['genre'].value_counts().keys().tolist()
count = dfCrit['genre'].value_counts().tolist()
del genre[35:52]
del count[35:52]
fig = plt.figure(figsize=(20, 13))
plt.xticks(rotation=90)
plt.xlabel("Genres")
plt.ylabel("Number of Games")
plt.title("Number of games in different genres")
plt.bar(genre,count)
# Out:
# <BarContainer object of 36 artists>

# %%
dfCrit.describe()
# Out:
#        positive_critics  neutral_critics  negative_critics  positive_users  \
# count       5685.000000      5685.000000       5685.000000     5685.000000
# mean          13.379595         7.971504          1.143712       28.813896
# std           16.211865         7.702913          2.924501      103.807966
# min            0.000000         0.000000          0.000000        0.000000
# 25%            3.000000         3.000000          0.000000        2.000000
# 50%            8.000000         6.000000          0.000000        5.000000
# 75%           17.000000        10.000000          1.000000       17.000000
# max          118.000000        65.000000         51.000000     2762.000000
#
#        neutral_users  negative_users    metascore   user_score
# count    5685.000000     5685.000000  5685.000000  5685.000000
# mean        8.655761       14.404046    71.882850    67.168514
# std        24.734058       85.040671    11.182417    13.543389
# ...

# %%
dfSale.describe()
# Out:
#                year      na_sales      eu_sales      jp_sales   other_sales  \
# count  16291.000000  16291.000000  16291.000000  16291.000000  16291.000000
# mean    2006.405561      0.265647      0.147731      0.078833      0.048426
# std        5.832412      0.822432      0.509303      0.311879      0.190083
# min     1980.000000      0.000000      0.000000      0.000000      0.000000
# 25%     2003.000000      0.000000      0.000000      0.000000      0.000000
# 50%     2007.000000      0.080000      0.020000      0.000000      0.010000
# 75%     2010.000000      0.240000      0.110000      0.040000      0.040000
# max     2020.000000     41.490000     29.020000     10.220000     10.570000
#
#        global_sales
# count  16291.000000
# mean       0.540910
# std        1.567345
# min        0.010000
# 25%        0.060000
# 50%        0.170000
# 75%        0.480000
# max       82.740000
